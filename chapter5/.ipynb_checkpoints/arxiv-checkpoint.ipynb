# %%
from datasets import load_dataset 
from umap import UMAP
from hdbscan import HDBSCAN 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
dataset = load_dataset("maartengr/arxiv_nlp")["train"]
abstracts = dataset["Abstracts"]
titles = dataset["Titles"]

# %%
# select am embedding generating model
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("thenlper/gte-small")
embeddings = embedding_model.encode(abstracts, show_progress_bar=True)
print("Embedding shape: ", embeddings.shape) # (n_abstracts,embed_dim)=(44949,384)
# Out:
# Batches: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1405/1405 [02:27<00:00,  9.49it/s]
# Embedding shape:  (44949, 384)

# %%
# dimension reduction with UMAP
umap_model = UMAP(
  n_components=5, min_dist=0.0, metric="cosine", random_state=42
)
reduced_embeddings = umap_model.fit_transform(embeddings)
print("Dimension-reduced shape: ", reduced_embeddings.shape) # (n_abstracts,reduced_dim)=(44949,5)
# Out:
# Dimension-reduced shape:  (44949, 5)

# %%
# clustering
# min_cluster_size: min number of points per cluster
hdbscan_model = HDBSCAN(
  min_cluster_size=50, metric="euclidean", cluster_selection_method="eom"
).fit(reduced_embeddings)
clusters = hdbscan_model.labels_ # list of ints
print("How many clusters did we generate? ", len(set(clusters)))
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# How many clusters did we generate?  154

# %%
# inspecting a few examples from cluster 0
cluster = 0
# np.where returns ([2,3,5,...])
for index in np.where(clusters==cluster)[0][:3]:
  print(abstracts[index][:300] + "... \n") # print first 300 chars of abstract
# Out:
#   This works aims to design a statistical machine translation from English text
# to American Sign Language (ASL). The system is based on Moses tool with some
# modifications and the results are synthesized through a 3D avatar for
# interpretation. First, we translate the input text to gloss, a written fo...
#
#   Researches on signed languages still strongly dissociate lin- guistic issues
# related on phonological and phonetic aspects, and gesture studies for
# recognition and synthesis purposes. This paper focuses on the imbrication of
# motion and meaning for the analysis, synthesis and evaluation of sign lang...
#
#   Modern computational linguistic software cannot produce important aspects of
# sign language translation. Using some researches we deduce that the majority of
# automatic sign language translation systems ignore many aspects when they
# generate animation; therefore the interpretation lost the truth inf...

# %%
# inspecting all clusters by REDUCE DIMENSION and PLOTTING
reduced_embeddings = UMAP(
  n_components=2, min_dist=0.0, metric="cosine", random_state=42
).fit_transform(embeddings)
# df: 4 columns of "x","y","title","cluster"
df = pd.DataFrame(reduced_embeddings, columns=["x","y"])
df["title"] = titles 
df["cluster"] = [str(c) for c in clusters]
# select outliers and non-outliers
to_plot = df.loc[df.cluster!="-1", :]
outliers = df.loc[df.cluster=="-1"]

# %%
to_plot
# Out:
#               x          y                                              title  \
# 3     -0.719299  11.587074  Network statistics on early English Syntax: St...
# 4      4.804537   9.203819  Segmentation and Context of Literary and Music...
# 5      3.277203  10.152081  International Standard for a Linguistic Annota...
# 6      3.255776  10.115393  A Formal Model of Dictionary Structure and Con...
# 8      3.147385   9.380138  Learning Probabilistic Models of Word Sense Di...
# ...         ...        ...                                                ...
# 44941 -1.304083  14.204062  Resolution of Indirect Anaphora in Japanese Se...
# 44942  1.457532  13.003902  Pronoun Resolution in Japanese Sentences Using...
# 44943  1.406531  12.996722  An Estimate of Referent of Noun Phrases in Jap...
# 44944  1.470580  12.967650  Resolution of Verb Ellipsis in Japanese Senten...
# 44947  3.468360  10.813979   HMM Specialization with Selective Lexicalization
#
#       cluster
# 3         135
# 4           7
# 5         110
# 6         110
# 8         109
# ...       ...
# 44941      15
# 44942      15
# 44943      15
# 44944      15
# 44947     138
#
# [30563 rows x 4 columns]

# %%
# Plot outliers and non-outliers separately
plt.scatter(outliers.x, outliers.y, alpha=0.05, s=2, c="grey")
plt.scatter(to_plot.x, to_plot.y, c=to_plot.cluster.astype(int), alpha=0.6, s=2, cmap="tab20b")
plt.axis("off")
# Out:
# (np.float64(-9.10010724067688),
#  np.float64(11.40207200050354),
#  np.float64(-1.463256824016571),
#  np.float64(16.46944545507431))

# %% [markdown]
# ## Topic modeling
# Topic representation consists of 2 steps multiplied with each other:
# $$
# \lVert tf_{x,c} \rVert \times \log \left( \frac{A}{cf_{x}} +1 \right)
# $$
# with \
# $A=$ total number of documents \
# $cf_{x}=$ number of documents containing that word \
# $\lVert tf_{x,c} \rVert=$ frequency of that word in cluster $c$

# %%
from bertopic import BERTopic
topic_model = BERTopic(
    embedding_model=embedding_model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    verbose=True
).fit(abstracts, embeddings)
# Out:
# 2025-12-19 14:12:56,154 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-12-19 14:13:52,173 - BERTopic - Dimensionality - Completed ✓
# 2025-12-19 14:13:52,177 - BERTopic - Cluster - Start clustering the reduced embeddings
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-12-19 14:13:54,776 - BERTopic - Cluster - Completed ✓
# 2025-12-19 14:13:54,798 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-12-19 14:13:58,832 - BERTopic - Representation - Completed ✓

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                           Name  \
# 0       -1  14386                               -1_the_of_and_to
# 1        0   2137                 0_question_qa_answer_questions
# 2        1   1993                   1_speech_asr_recognition_end
# 3        2   1240  2_summarization_summaries_summary_abstractive
# 4        3    877               3_translation_nmt_machine_neural
# ..     ...    ...                                            ...
# 149    148     53           148_emoji_emojis_emoticons_sentiment
# 150    149     53       149_multimodal_modality_sentiment_fusion
# 151    150     53           150_counseling_mental_therapy_health
# 152    151     52            151_gans_gan_adversarial_generation
# 153    152     51                152_moe_experts_mixture_routing
#
#                                         Representation  \
# 0    [the, of, and, to, in, we, for, language, that...
# 1    [question, qa, answer, questions, answering, a...
# 2    [speech, asr, recognition, end, acoustic, spea...
# 3    [summarization, summaries, summary, abstractiv...
# 4    [translation, nmt, machine, neural, bleu, engl...
# ..                                                 ...
# 149  [emoji, emojis, emoticons, sentiment, social, ...
# 150  [multimodal, modality, sentiment, fusion, moda...
# 151  [counseling, mental, therapy, health, psychoth...
# 152  [gans, gan, adversarial, generation, generativ...
# 153  [moe, experts, mixture, routing, expert, spars...
#
#                                    Representative_Docs
# 0    [  Many users communicate with chatbots and AI...
# 1    [  In multi-hop QA, answering complex question...
# 2    [  We introduce Wav2Seq, the first self-superv...
# 3    [  Abstractive summarization systems generally...
# 4    [  Neural machine translation~(NMT) is ineffec...
# ..                                                 ...
# 149  [  The frequent use of Emojis on social media ...
# 150  [  Multimodal sentiment analysis is an importa...
# 151  [  Mental health care poses an increasingly se...
# 152  [  Text generation is of particular interest i...
# 153  [  The Mixture of Experts (MoE) models are an ...
#
# [154 rows x 5 columns]

# %%
# which keywords represent best of topic 0
topic_model.get_topic(0)
# Out:
# [('question', np.float64(0.021749968884602386)),
#  ('qa', np.float64(0.016270096848583302)),
#  ('answer', np.float64(0.016163256712999598)),
#  ('questions', np.float64(0.016140977385855817)),
#  ('answering', np.float64(0.015068518153332116)),
#  ('answers', np.float64(0.010039238298453063)),
#  ('retrieval', np.float64(0.009529823725027559)),
#  ('comprehension', np.float64(0.008026567012170546)),
#  ('reading', np.float64(0.007476545733680139)),
#  ('hop', np.float64(0.0063362732787493395))]

# %%
# get topics highly related to "topic modeling"
topic_model.find_topics("topic modeling")
# Out:
# ([23, -1, 37, 35, 79],
#  [np.float32(0.9544623),
#   np.float32(0.9116207),
#   np.float32(0.907876),
#   np.float32(0.9049681),
#   np.float32(0.9035181)])

# %%
topic_model.get_topic(23)
# Out:
# [('topic', np.float64(0.06680186320763085)),
#  ('topics', np.float64(0.03553390169440711)),
#  ('lda', np.float64(0.016077847672595808)),
#  ('document', np.float64(0.012881111526123997)),
#  ('latent', np.float64(0.012774266132146531)),
#  ('documents', np.float64(0.012477022152895898)),
#  ('modeling', np.float64(0.01194676603914678)),
#  ('dirichlet', np.float64(0.009309560451212567)),
#  ('word', np.float64(0.008454842288559467)),
#  ('clustering', np.float64(0.008180377340569063))]

# %%
# topic_model.topics_ => list of topic ids of <abstract>s 
title_loc = titles.index("BERTopic: Neural topic modeling with a class-based TF-IDF procedure")
topic_model.topics_[title_loc]
# Out:
# 23

# %%
# # Visualize topics (clusters)
# fig = topic_model.visualize_documents(
#     titles,
#     reduced_embeddings=reduced_embeddings,
#     width=1200,
#     hide_annotations=True
# )
# fig.update_layout(font=dict(size=16))

# %%
# Visualize each topic, with the frequency of its main keywords
topic_model.visualize_barchart()

# %%
# Visualize relationships between topics
topic_model.visualize_heatmap(n_clusters=30)

# %%
# visualize hierarchical structure of topics
topic_model.visualize_hierarchy()

# %% [markdown]
# ## Reranker: improve order of words of a topic

# %%
from copy import deepcopy
original_topics = deepcopy(topic_model.topic_representations_) # {0: [('question',0.022),('qa',0.016),], 1: [...], }
print(original_topics)
# Out:
# {-1: [('the', np.float64(0.006016439155542787)), ('of', np.float64(0.0059806797586496015)), ('and', np.float64(0.0059714383660381155)), ('to', np.float64(0.0057895137747943914)), ('in', np.float64(0.0056723300652906875)), ('we', np.float64(0.005457276507542094)), ('for', np.float64(0.005280680006554715)), ('language', np.float64(0.00524588282873733)), ('that', np.float64(0.0051676714420516015)), ('on', np.float64(0.005070391172097444))], 0: [('question', np.float64(0.021749968884602386)), ('qa', np.float64(0.016270096848583302)), ('answer', np.float64(0.016163256712999598)), ('questions', np.float64(0.016140977385855817)), ('answering', np.float64(0.015068518153332116)), ('answers', np.float64(0.010039238298453063)), ('retrieval', np.float64(0.009529823725027559)), ('comprehension', np.float64(0.008026567012170546)), ('reading', np.float64(0.007476545733680139)), ('hop', np.float64(0.0063362732787493395))], 1: [('speech', np.float64(0.02896341131504021)), ('asr', np.float64(0.019475014522681834)), ('recognition', np.float64(0.013966296465733904)), ('end', np.float64(0.010635360734207368)), ('acoustic', np.float64(0.00997735821733446)), ('speaker', np.float64(0.0070444497106435236)), ('audio', np.float64(0.006789020066392473)), ('wer', np.float64(0.006726213801839795)), ('error', np.float64(0.00662969541222933)), ('the', np.float64(0.006430379362373267))], 2: [('summarization', np.float64(0.039135629135580004)), ('summaries', np.float64(0.023884010695412735)), ('summary', np.float64(0.01931342905238599)), ('abstractive', np.float64(0.016191294612433002)), ('document', np.float64(0.011511228696186152)), ('extractive', np.float64(0.009558944994604206)), ('rouge', np.float64(0.009015150375808556)), ('the', np.float64(0.0064188339269947)), ('evaluation', np.float64(0.006084579937226923)), ('factual', np.float64(0.006001420271577007))], 3: [('translation', np.float64(0.034341889057737725)), ('nmt', np.float64(0.02552818503146067)), ('machine', np.float64(0.01623706763646056)), ('neural', np.float64(0.010604572648456701)), ('bleu', np.float64(0.010371283533150037)), ('english', np.float64(0.00965245427578803)), ('parallel', np.float64(0.008813456577181722)), ('resource', np.float64(0.008568243365767008)), ('target', np.float64(0.008399715966344899)), ('source', np.float64(0.00819620774409616))], 4: [('hate', np.float64(0.0344049375780464)), ('offensive', np.float64(0.019724273754429516)), ('speech', np.float64(0.014951818627085492)), ('detection', np.float64(0.014241328455944165)), ('toxic', np.float64(0.012352764217938106)), ('social', np.float64(0.011604611775076688)), ('content', np.float64(0.010688420761407049)), ('online', np.float64(0.01011082352442976)), ('toxicity', np.float64(0.010068605149045864)), ('media', np.float64(0.009769449875045343))], 5: [('gender', np.float64(0.04250085801298832)), ('bias', np.float64(0.039563271715815744)), ('biases', np.float64(0.02573221660597081)), ('debiasing', np.float64(0.012194573946157203)), ('fairness', np.float64(0.010934192072725142)), ('stereotypes', np.float64(0.009343051551931495)), ('social', np.float64(0.008629983583589258)), ('in', np.float64(0.007952791165827552)), ('biased', np.float64(0.0068543000350662145)), ('embeddings', np.float64(0.006439243487209184))], 6: [('relation', np.float64(0.03996114325099494)), ('extraction', np.float64(0.02824234499770643)), ('relations', np.float64(0.016464202422568405)), ('re', np.float64(0.016151337042121097)), ('entity', np.float64(0.013139528382057935)), ('entities', np.float64(0.010081243149039227)), ('ie', np.float64(0.009493671256512095)), ('information', np.float64(0.0077022841773944735)), ('level', np.float64(0.006718679773781724)), ('distant', np.float64(0.006640428612247433))], 7: [('ner', np.float64(0.04957667151564264)), ('entity', np.float64(0.026927986638669108)), ('named', np.float64(0.026211780000683277)), ('recognition', np.float64(0.01705817360005601)), ('entities', np.float64(0.013235089440032833)), ('nested', np.float64(0. ...

# %%
# Show difference between topics words before- and after-representation-model
def topic_differences(model, original_topics, nr_topics=5):
    df = pd.DataFrame(columns=["Topic", "Original", "Updated"])
    # 1st col: 0,1,2..; 2nd col:"a"|"b"|"c"..., 3rd col: "a"|"d"|"z"...
    for topic in range(nr_topics):
        # extract 5 words per topic
        old_words_and_probs = original_topics[topic] # [('question',0.22),('qa',0.16),...]
        new_words_and_probs = model.get_topic(topic)
        # list(zip()) => list of ['question','qa',...] and [0.22,0.16,...] 
        og_words = " | ".join( list(zip(*words))[0][:5] )
        new_words = " | ".join( li
